# %%
ans_path="ans.txt"
exp_path="image/ryan/ryan_line.txt"
ans_txt = ""
with open(ans_path, "r") as f:
    ans_txt = f.read()
with open(exp_path, "r") as f:
    exp_txt = f.read()

# %%
ans_txt==exp_txt
# Out:
# True

# %%
import numpy as np


img = np.array([
    [0, 1, 0],
    [2, 1, 3],
    [0, 1, 1]
])

coords = np.argwhere(img == 1)

print(coords)


coords = coords[np.lexsort((coords[:, 1], -coords[:, 0]))]

print(coords)
# Out:
# [[0 1]
#  [1 1]
#  [2 1]
#  [2 2]]
# [[2 1]
#  [2 2]
#  [1 1]
#  [0 1]]
